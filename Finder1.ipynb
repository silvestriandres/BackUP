# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
business = pd.read_csv('fiuba_4_postulaciones.csv')
business.head()
# Out:
#       idaviso idpostulante     fechapostulacion
# 0  1112257047         NM5M  2018-01-15 16:22:34
# 1  1111920714         NM5M  2018-02-06 09:04:50
# 2  1112346945         NM5M  2018-02-22 09:04:47
# 3  1112345547         NM5M  2018-02-22 09:04:59
# 4  1112237522         5awk  2018-01-25 18:55:03

# %%
business_index = business.index
business_columns = business.columns
business_data = business.values

# %%
business_columns
# Out:
# Index([u'idaviso', u'idpostulante', u'fechapostulacion'], dtype='object')

# %%
business.dtypes
# Out:
# idaviso              int64
# idpostulante        object
# fechapostulacion    object
# dtype: object

# %%
business.isnull().any()
# Out:
# idaviso             False
# idpostulante        False
# fechapostulacion    False
# dtype: bool

# %%
business['fechapostulacion'].describe()
# Out:
# count                 3401623
# unique                1940105
# top       2018-01-17 07:03:36
# freq                       25
# Name: fechapostulacion, dtype: object

# %%
business['dia_semana'] = pd.to_datetime(business['fechapostulacion'])

# %%
business['dia_semana'].dt.weekday_name
# Out:
# 0             Monday
# 1            Tuesday
# 2           Thursday
# 3           Thursday
# 4           Thursday
# 5             Monday
# 6          Wednesday
# 7          Wednesday
# 8          Wednesday
# 9             Friday
# 10            Sunday
# 11            Monday
# 12         Wednesday
# 13         Wednesday
# 14         Wednesday
# 15         Wednesday
# 16         Wednesday
# 17         Wednesday
# 18         Wednesday
# 19         Wednesday
# 20         Wednesday
# 21         Wednesday
# 22            Friday
# 23           Tuesday
# 24         Wednesday
# 25         Wednesday
# 26          Saturday
# 27         Wednesday
# 28            Friday
# 29            Sunday
#              ...
# 3401593    Wednesday
# 3401594    Wednesday
# 3401595    Wednesday
# 3401596    Wednesday
# 3401597    Wednesday
# 3401598    Wednesday
# 3401599    Wednesday
# 3401600    Wednesday
# 3401601    Wednesday
# 3401602    Wednesday
# 3401603    Wednesday
# 3401604    Wednesday
# ...

# %%
business['dia_semana'].values_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-22f340c626a7> in <module>()
# ----> 1 business['dia_semana'].values_count()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'values_count'

# %%
business
# Out:
#             idaviso idpostulante     fechapostulacion          dia_semana
# 0        1112257047         NM5M  2018-01-15 16:22:34 2018-01-15 16:22:34
# 1        1111920714         NM5M  2018-02-06 09:04:50 2018-02-06 09:04:50
# 2        1112346945         NM5M  2018-02-22 09:04:47 2018-02-22 09:04:47
# 3        1112345547         NM5M  2018-02-22 09:04:59 2018-02-22 09:04:59
# 4        1112237522         5awk  2018-01-25 18:55:03 2018-01-25 18:55:03
# 5        1112277633         5awk  2018-01-29 13:34:44 2018-01-29 13:34:44
# 6        1112302347         5awk  2018-02-07 20:49:22 2018-02-07 20:49:22
# 7        1112291495         5awk  2018-02-07 20:50:13 2018-02-07 20:50:13
# 8        1112304011         5awk  2018-02-07 20:51:15 2018-02-07 20:51:15
# 9        1112326289         5awk  2018-02-09 20:24:57 2018-02-09 20:24:57
# 10       1112303543         5awk  2018-02-18 23:49:34 2018-02-18 23:49:34
# 11       1112315393         5awk  2018-02-19 00:01:20 2018-02-19 00:01:20
# ...

# %%
business['dia_semana'] = business['dia_semana'].dt.weekday_name

# %%
business['dia_semana'].count()
# Out:
# 3401623

# %%
business['dia_semana'].value_counts()
# Out:
# Wednesday    677836
# Monday       668310
# Tuesday      658428
# Thursday     506163
# Friday       446698
# Sunday       226857
# Saturday     217331
# Name: dia_semana, dtype: int64

# %%
business['mes'] = pd.to_datetime(business['fechapostulacion'])
business['mes'] = business['mes'].dt.month

# %%
business['mes'].value_counts()
# Out:
# 2    2125425
# 1    1276198
# Name: mes, dtype: int64

# %%
business['año'] = pd.to_datetime(business['fechapostulacion'])
business['año'] = business['año'].dt.year
business['año'].value_counts()
# Out:
# 2018    3401623
# Name: año, dtype: int64

# %%
 pd.to_datetime(business['fechapostulacion']).dt.monthday
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-2f57636235b0> in <module>()
# ----> 1 pd.to_datetime(business['fechapostulacion']).dt.monthday
#
# AttributeError: 'DatetimeProperties' object has no attribute 'monthday'

# %%
 pd.to_datetime(business['fechapostulacion']).dt.day
# Out:
# 0          15
# 1           6
# 2          22
# 3          22
# 4          25
# 5          29
# 6           7
# 7           7
# 8           7
# 9           9
# 10         18
# 11         19
# 12         28
# 13         28
# 14         28
# 15         28
# 16         28
# 17         28
# 18         28
# 19         28
# 20         24
# 21         24
# 22         26
# 23         30
# 24         31
# 25         31
# 26          3
# 27          7
# 28          9
# 29         11
#            ..
# 3401593    28
# 3401594    28
# 3401595    28
# 3401596    28
# 3401597    28
# 3401598    28
# 3401599    28
# 3401600    28
# 3401601    28
# 3401602    28
# 3401603    28
# 3401604    28
# 3401605    28
# 3401606    28
# 3401607    28
# 3401608    28
# 3401609    28
# 3401610    28
# 3401611    28
# 3401612    28
# 3401613    28
# 3401614    28
# 3401615    28
# 3401616    28
# 3401617    28
# 3401618    28
# 3401619    28
# 3401620    28
# 3401621    28
# 3401622    28
# ...

# %%
business['dia'] = pd.to_datetime(business['fechapostulacion'])
business['dia'] = business['dia'].dt.day
business['dia'].value_counts()
# Out:
# 19    205593
# 22    201673
# 26    196134
# 15    185118
# 23    176426
# 16    170402
# 20    165437
# 21    158073
# 27    155478
# 28    153714
# 24    141491
# 25    129791
# 17    129443
# 18    124249
# 30     97352
# 29     96300
# 5      91680
# 31     88869
# 6      85786
# 14     85201
# 1      77554
# 7      75788
# 2      69328
# 8      67579
# 9      66963
# 13     44363
# 4      35350
# 12     33669
# 3      32543
# 10     32138
# 11     28138
# Name: dia, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

avisos_online = pd.read_csv('fiuba_6_avisos_detalle.csv')
avisos_online.head()
# Out:
#       idaviso  idpais                                         titulo  \
# 0     8725750       1               VENDEDOR/A PROVINCIA DE SANTA FE
# 1    17903700       1                                     Enfermeras
# 2  1000150677       1                                 Chofer de taxi
# 3  1000610287       1  CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4  1000872556       1  Operarios de Planta - Rubro Electrodomésticos
#
#                                          descripcion        nombre_zona  \
# 0  <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1  <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2  <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4  <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
#
#   ciudad       mapacalle tipo_de_trabajo         nivel_laboral nombre_area  \
# ...

# %%
avisos_online[avisos_online['nombre_area'] == 'Ventas']['nombre_zona'].value_counts()
# Out:
# Gran Buenos Aires              1521
# Capital Federal                 137
# Buenos Aires (fuera de GBA)       1
# Name: nombre_zona, dtype: int64

# %%
avisos_online['nombre_area'].value_counts()
# Out:
# Ventas                                   1659
# Comercial                                 983
# Administración                            901
# Producción                                821
# Programación                              576
# Contabilidad                              416
# Tecnologia / Sistemas                     388
# Atención al Cliente                       347
# Mantenimiento                             324
# Recursos Humanos                          235
# Gastronomia                               234
# Oficios y Profesiones                     209
# Soporte Técnico                           203
# Logística                                 200
# Call Center                               191
# Almacén / Depósito / Expedición           184
# Compras                                   170
# Otros                                     153
# Marketing                                 153
# Administración de Personal                152
# ...

# %%
fig=plt.figure()
ax = fig.add_subplot(111)

plt.title('Areas por Zona: Histogram',fontsize=16,fontweight='bold')
ax.set_xlabel('Zonas')
avisos_online[avisos_online['nombre_area'] == 'Ventas']['nombre_zona'].value_counts().plot.hist(color='darksalmon', figsize=(8, 4))

plt.show()

# %%
avisos_online[avisos_online['nombre_area'] == 'Ventas']['nombre_zona'].value_counts()
# Out:
# Gran Buenos Aires              1521
# Capital Federal                 137
# Buenos Aires (fuera de GBA)       1
# Name: nombre_zona, dtype: int64

# %%
areaporzona = avisos_online[avisos_online['nombre_area'] == 'Ventas']['nombre_zona'].value_counts()

# %%
areaporzona.set_index('nombre_zona')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-f428850ec38e> in <module>()
# ----> 1 areaporzona.set_index('nombre_zona')
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %%
avisos_online.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13534 entries, 0 to 13533
# Data columns (total 11 columns):
# idaviso                 13534 non-null int64
# idpais                  13534 non-null int64
# titulo                  13534 non-null object
# descripcion             13534 non-null object
# nombre_zona             13534 non-null object
# ciudad                  47 non-null object
# mapacalle               872 non-null object
# tipo_de_trabajo         13534 non-null object
# nivel_laboral           13534 non-null object
# nombre_area             13534 non-null object
# denominacion_empresa    13529 non-null object
# dtypes: int64(2), object(9)
# memory usage: 1.1+ MB

# %%
avisos_online.head()
# Out:
#       idaviso  idpais                                         titulo  \
# 0     8725750       1               VENDEDOR/A PROVINCIA DE SANTA FE
# 1    17903700       1                                     Enfermeras
# 2  1000150677       1                                 Chofer de taxi
# 3  1000610287       1  CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4  1000872556       1  Operarios de Planta - Rubro Electrodomésticos
#
#                                          descripcion        nombre_zona  \
# 0  <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1  <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2  <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4  <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
#
#   ciudad       mapacalle tipo_de_trabajo         nivel_laboral nombre_area  \
# ...

# %%
avisos_online[avisos_online['nombre_area'] == 'Ventas']
# Out:
#           idaviso  idpais                                             titulo  \
# 5      1001135716       1      Vendedor Viajante TUCUMAN/SANTIAGO DEL ESTERO
# 6      1001326344       1           Vendedor Viajante RECONQUISTA/AVELLANEDA
# 7      1001455648       1            Vendedor Viajante PILAR / ESCOBAR/TIGRE
# 11     1002181678       1                 Vendedor Viajante TIERRA DEL FUEGO
# 12     1002308544       1   Preventistas Importante Distribuidora de Bebidas
# 17     1110383223       1  Vendedor Viajante ADROGUE/LANUS/AVELLANEDA/LOM...
# 23     1110640369       1                     VENDEDORES DE PLANES DE AHORRO
# 30     1110968766       1  Vendedores eventuales para The Palace - Luxury...
# 40     1111170217       1  Preventistas  Experiencia en Distribuidoras zo...
# 52     1111295896       1                                Cajeros-Repositores
# 53     1111299783       1             Vendedores de Electrodomesticos Moreno
# ...

# %%
fig=plt.figure()
ax = fig.add_subplot(111)

plt.title('Areas por Zona: Histogram',fontsize=16,fontweight='bold')
ax.set_xlabel('Zonas')
avisos_online[avisos_online['nombre_area'] == 'Ventas']['nombre_zona'].plot.hist(color='darksalmon', figsize=(8, 4))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-f7f8798615b4> in <module>()
#       4 plt.title('Areas por Zona: Histogram',fontsize=16,fontweight='bold')
#       5 ax.set_xlabel('Zonas')
# ----> 6 avisos_online[avisos_online['nombre_area'] == 'Ventas']['nombre_zona'].plot.hist(color='darksalmon', figsize=(8, 4))
#       7
#       8 plt.show()
#
# /usr/local/lib/python2.7/dist-packages/pandas/plotting/_core.pyc in hist(self, bins, **kwds)
#    2589         axes : matplotlib.AxesSubplot or np.array of them
#    2590         """
# -> 2591         return self(kind='hist', bins=bins, **kwds)
#    2592
#    2593     def kde(self, **kwds):
#
# ...

# %%
areazona = pd.DataFrame([avisos_online[avisos_online['nombre_area'] == 'Ventas']['nombre_zona'].value_counts()])

# %%
areazona
# Out:
#              Gran Buenos Aires  Capital Federal  Buenos Aires (fuera de GBA)
# nombre_zona               1521              137                            1

# %%
areazona = areazona.transpose
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-042b1fb6450d> in <module>()
# ----> 1 areazona = areazona.transpose
#
# AttributeError: 'function' object has no attribute 'transpose'

# %%
areazona = areazona.transpose()

# %%
areazona
areazona.plot(kind='bar',figsize=(16,8),rot=85,title='Top Business');
ax=plt.gca()
ax.set_ylabel('Cantidad de Postulaciones');
ax.set_xlabel('Zonas Afectadas');

# %%
fig=plt.figure()
ax = fig.add_subplot(111)

plt.title('Areas por Zona: Histogram',fontsize=16,fontweight='bold')
ax.set_xlabel('Zonas')
areazona['nombre_zona'].plot.hist(color='darksalmon', figsize=(8, 4))

plt.show()

# %% [markdown]
# EJEMPLO
