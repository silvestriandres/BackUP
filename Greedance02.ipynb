# %%
studentMat = pd.read_csv('student-mat.csv')
studentMat.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-72bdd9ed821d> in <module>()
# ----> 1 studentMat = pd.read_csv('student-mat.csv')
#       2 studentMat.head(5)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
studentMat = pd.read_csv('student-mat.csv')
studentMat.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
studentPor = pd.read_csv('student-por.csv')
studentPor.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
studentMat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %%
studentMat['school'].value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
studentPor['school'].value_counts()
# Out:
# GP    423
# MS    226
# Name: school, dtype: int64

# %%
studentMat['materia'] = "matematica"

# %%
studentMat['materia'].value_counts()
# Out:
# matematica    395
# Name: materia, dtype: int64

# %%
studentPor['materia'] = "portugues"
studentPor['materia'].value_counts()
# Out:
# portugues    649
# Name: materia, dtype: int64

# %%
studentTotal=studentMat.append(studentPor)

# %%
studentTotal.tail(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#        ...     freetime goout  Dalc  Walc  health absences  G1  G2  G3  \
# 644    ...            4     2     1     2       5        4  10  11  10
# 645    ...            3     4     1     1       1        4  15  15  16
# 646    ...            1     1     1     1       5        6  11  12   9
# 647    ...            4     5     3     4       2        6  10  10  10
# 648    ...            4     1     3     4       5        4  10  11  11
#
#        materia
# 644  portugues
# 645  portugues
# 646  portugues
# ...

# %%
studentTotal['materia'].value_counts()
# Out:
# portugues     649
# matematica    395
# Name: materia, dtype: int64

# %%
studentTotal['promedio'] = (studentTotal['G1'] + studentTotal['G2'] + studentTotal['G3'])/3

# %%
studentTotal.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#      ...     goout Dalc  Walc  health  absences  G1  G2  G3     materia  \
# 0    ...         4    1     1       3         6   5   6   6  matematica
# 1    ...         3    1     1       3         4   5   5   6  matematica
# 2    ...         2    2     3       3        10   7   8  10  matematica
# 3    ...         2    1     1       5         2  15  14  15  matematica
# 4    ...         2    1     2       5         4   6  10  10  matematica
#
#     promedio
# 0   5.666667
# 1   5.333333
# 2   8.333333
# 3  14.666667
# 4   8.666667
#
# ...

# %%
studentTotal.groupby(['school','materia'])

# %%
studentTotal['contador'] = 1

# %%
studentTotal.groupby(['school','materia']).agg({'contador':'sum'})
# Out:
#                    contador
# school materia
# GP     matematica       349
#        portugues        423
# MS     matematica        46
#        portugues        226

# %%
studentTotal.groupby(['school','materia']).agg({'promedio':'mean'})
# Out:
#                     promedio
# school materia
# GP     matematica  10.737345
#        portugues   12.235619
# MS     matematica  10.239130
#        portugues   10.482301

# %%
studentTotal.groupby('paid').agg({'promedio':'mean'})
# Out:
#        promedio
# paid
# no    11.328479
# yes   11.037879

# %%
studentTotal['casa'] = ((studentTotal['Mjob'] == "at_home") and (studentTotal['Fjob'] == "at_home"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-2d7da3132b21> in <module>()
# ----> 1 studentTotal['casa'] = ((studentTotal['Mjob'] == "at_home") and (studentTotal['Fjob'] == "at_home"))
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
studentTotal.groupby(['Mjob','Fjob']).agg({'promedio':'mean'})
# Out:
#                     promedio
# Mjob     Fjob
# at_home  at_home   12.000000
#          health    11.250000
#          other     10.309091
#          services  10.176471
#          teacher    6.833333
# health   at_home    9.000000
#          health    13.355556
#          other     12.263158
#          services  12.320000
#          teacher   14.111111
# other    at_home   10.105263
#          health    11.333333
#          other     10.989547
#          services  10.950450
#          teacher   11.523810
# services at_home    9.794872
#          health    10.458333
#          other     11.900000
#          services  11.215686
#          teacher   13.604167
# teacher  at_home   11.166667
#          health    11.518519
#          other     11.578231
#          services  11.800000
#          teacher   13.833333

# %%
studentTotal['MFPromedio'] = (studentTotal['Medu'] + studentTotal['Fedu']) / 2

# %%
studentTotal.groupby('address').agg({'MFPromedio':'mean'})
# Out:
#          MFPromedio
# address
# R          2.219298
# U          2.599473

# %% [markdown]
# # =====================================================
# # A continuación hacemos todo lo referente a UFO.-
# # =====================================================

# %%
UFOComplete = pd.read_csv('complete.csv')
UFOComplete.head(5)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-b7f1bf9be5f3> in <module>()
# ----> 1 UFOComplete = pd.read_csv('complete.csv')
#       2 UFOComplete.head(5)
#
# ...

# %%
UFOScrubbed = pd.read_csv('scrubbed.csv')
UFOScrubbed.head(5)
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
# ...

# %%
UFOScrubbed.info()
UFOScrubbed['datetime'].head(5)
UFOScrubbed['fecha'] = UFOScrubbed['datetime'].str.split(' ').str.get(0)
UFOScrubbed['año'] = UFOScrubbed['fecha'].str.split('/').str.get(2)
UFOScrubbed['mes'] = UFOScrubbed['fecha'].str.split('/').str.get(0)
UFOScrubbed['año'].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 13 columns):
# datetime                80332 non-null object
# city                    80332 non-null object
# state                   74535 non-null object
# country                 70662 non-null object
# shape                   78400 non-null object
# duration (seconds)      80332 non-null object
# duration (hours/min)    80332 non-null object
# comments                80317 non-null object
# date posted             80332 non-null object
# latitude                80332 non-null object
# longitude               80332 non-null float64
# año                     80332 non-null object
# contador                80332 non-null int64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 8.0+ MB
# 0    1949
# 1    1949
# 2    1955
# 3    1956
# 4    1960
# Name: año, dtype: object

# %%
UFOScrubbed['mes'].value_counts()
# Out:
# 7     9520
# 8     8636
# 6     8152
# 9     7589
# 10    7407
# 11    6739
# 1     5689
# 12    5665
# 4     5527
# 3     5450
# 5     5293
# 2     4665
# Name: mes, dtype: int64

# %%
#UFOScrubbed['año'] = pd.to_datetime(UFOScrubbed['datetime'], errors='coerce').dt.year

# %%
UFOScrubbed['año']
# Out:
# 0        1949
# 1        1949
# 2        1955
# 3        1956
# 4        1960
# 5        1961
# 6        1965
# 7        1965
# 8        1966
# 9        1966
# 10       1968
# 11       1968
# 12       1970
# 13       1970
# 14       1971
# 15       1972
# 16       1972
# 17       1973
# 18       1973
# 19       1974
# 20       1974
# 21       1974
# 22       1975
# 23       1976
# 24       1976
# 25       1977
# 26       1977
# 27       1978
# 28       1979
# 29       1979
#          ...
# 80302    2012
# 80303    2012
# 80304    2012
# 80305    2012
# 80306    2012
# 80307    2012
# 80308    2012
# 80309    2012
# 80310    2012
# 80311    2012
# 80312    2012
# 80313    2013
# 80314    2013
# 80315    2013
# 80316    2013
# 80317    2013
# 80318    2013
# 80319    2013
# 80320    2013
# 80321    2013
# 80322    2013
# 80323    2013
# 80324    2013
# 80325    2013
# 80326    2013
# 80327    2013
# 80328    2013
# 80329    2013
# 80330    2013
# 80331    2013
# ...

# %%
# Existen 143 registros de avistajes en Canadá durante el año 2010 
#UFOScrubbed['contador'] = 1
UFOCanada = UFOScrubbed[UFOScrubbed['country'] == "ca"]
UFOCanada['año'].value_counts() #.groupby('año').agg({'contador':'sum'})
# Out:
# 2003    294
# 2004    265
# 2013    248
# 2012    242
# 2005    183
# 2002    166
# 2007    160
# 2006    143
# 2010    137
# 2001    136
# 2009    134
# 2011    127
# 2008    119
# 2000    102
# 1999     96
# 1998     61
# 2014     45
# 1997     40
# 1996     29
# 1995     18
# 1994     17
# 1990     14
# 1977     12
# 1978     11
# 1987     11
# 1993     11
# 1992     10
# 1975     10
# 1969      9
# 1988      9
#        ...
# 1973      8
# 1972      8
# 1991      8
# 1974      7
# 1966      7
# 1979      6
# 1989      6
# 1980      6
# 1982      6
# 1971      5
# 1960      5
# 1968      4
# 1976      4
# 1981      4
# 1983      4
# 1963      3
# 1986      3
# 1952      2
# 1953      2
# 1951      2
# 1954      2
# 1961      2
# 1962      2
# 1967      2
# 1965      2
# 1936      1
# 1958      1
# 1955      1
# 1964      1
# 1946      1
# Name: año, Length: 63, dtype: int64

# %%
# Existen 2184 registros de avistajes en Estados Unidos durante el año 2000. 
UFOusa = UFOScrubbed[UFOScrubbed['country'] == "us"]
UFOusa['año'].value_counts()
# Out:
# 2012    6320
# 2013    6056
# 2011    4379
# 2008    4017
# 2009    3677
# 2010    3548
# 2007    3470
# 2004    3244
# 2005    3228
# 2003    2958
# 2006    2884
# 2001    2445
# 2002    2439
# 1999    2253
# 2000    2184
# 2014    1964
# 1998    1404
# 1997    1009
# 1995     915
# 1996     646
# 1994     324
# 1978     258
# 1975     247
# 1993     228
# 1976     222
# 1974     219
# 1977     206
# 1989     200
# 1980     194
# 1979     191
#         ...
# 1962      56
# 1960      51
# 1959      43
# 1958      42
# 1961      41
# 1956      39
# 1954      38
# 1952      37
# 1947      33
# 1953      26
# 1955      25
# 1950      21
# 1949      15
# 1951      13
# 1946       8
# 1948       7
# 1945       7
# 1939       3
# 1944       3
# 1910       2
# 1931       2
# 1942       2
# 1937       2
# 1925       1
# 1941       1
# 1943       1
# 1934       1
# 1936       1
# 1929       1
# 1920       1
# Name: año, Length: 83, dtype: int64

# %%
# Existen 963 ufos reportados con forma de chevron
UFOScrubbed['shape'].value_counts()
# Out:
# light        16565
# triangle      7865
# circle        7608
# fireball      6208
# other         5649
# unknown       5584
# sphere        5387
# disk          5213
# oval          3733
# formation     2457
# cigar         2057
# changing      1962
# flash         1328
# rectangle     1297
# cylinder      1283
# diamond       1178
# chevron        952
# egg            759
# teardrop       750
# cone           316
# cross          233
# delta            7
# crescent         2
# round            2
# flare            1
# pyramid          1
# dome             1
# hexagon          1
# changed          1
# Name: shape, dtype: int64

# %%
UFOLosAngeles = UFOScrubbed[UFOScrubbed['city'] == "los angeles"]

# %%
 UFOLosAngeles = UFOLosAngeles[UFOLosAngeles['state'] == "ca"]

# %%
UFOLosAngeles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 146 to 80171
# Data columns (total 13 columns):
# datetime                352 non-null object
# city                    352 non-null object
# state                   352 non-null object
# country                 352 non-null object
# shape                   347 non-null object
# duration (seconds)      352 non-null object
# duration (hours/min)    352 non-null object
# comments                352 non-null object
# date posted             352 non-null object
# latitude                352 non-null object
# longitude               352 non-null float64
# año                     348 non-null float64
# contador                352 non-null int64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 38.5+ KB

# %%
#  La forma con mayor cantidad de registros en Los Angeles, CA es la forma de triangulo. 
UFOLosAngeles['shape'].value_counts()
# Out:
# light        63
# circle       36
# triangle     30
# fireball     29
# disk         29
# unknown      26
# sphere       25
# other        21
# cigar        16
# oval         16
# changing     13
# formation    11
# rectangle     5
# chevron       5
# egg           5
# flash         5
# diamond       4
# teardrop      4
# cone          3
# cylinder      1
# Name: shape, dtype: int64

# %%
UFOMontana = UFOScrubbed[UFOScrubbed['state'] == "mo"]
UFOMontana = UFOMontana[UFOMontana['country'] == "us"]
UFOMontana['shape'].value_counts()
# Out:
# light        301
# triangle     178
# fireball     125
# other        111
# circle       104
# sphere       102
# unknown      102
# disk          94
# oval          56
# cigar         54
# cylinder      36
# changing      30
# chevron       28
# formation     24
# diamond       22
# rectangle     19
# flash         15
# teardrop      12
# egg            8
# cone           5
# cross          4
# delta          1
# Name: shape, dtype: int64

# %%
# El avistaje mas corto ocurrido en Marzo del 2007 ocurrió en la ciudad de Denver 
UFOScrubbed.sort_values('duration (seconds)')
# Out:
#                datetime                                    city state country  \
# 70587   8/30/2002 13:45             kerry (republic of ireland)   NaN     NaN
# 70393   8/29/2002 23:45                                  toledo    or      us
# 67354   8/17/2013 24:00                     abbotsford (canada)    bc      ca
# 78381   9/29/1999 14:30          warnambool&#44 vic (australia)   NaN     NaN
# 75324   9/17/2006 03:30                               las vegas    nv      us
# 68576    8/2/2004 10:35                                     roy    ut      us
# 79159    9/4/2008 06:15                                eldridge    al      us
# 76835   9/22/1998 23:55                                  ladson    sc      us
# 79486    9/6/1995 21:30              grand canyon&#44 north rim    az     NaN
# 75190   9/16/2011 11:16                     sisters (in-flight)    or      us
# 66102   8/14/2012 22:10                                  seatac    wa      us
# ...

# %%
UFOScrubbed.sort_values('duration (seconds)')

UFOResume = UFOScrubbed[UFOScrubbed['año'] == "2004"]

# %%
UFOResume = UFOResume[UFOResume['mes'] == "3"]

# %%
UFOResume['duration (seconds)'] = pd.to_numeric(UFOResume['duration (seconds)'])
UFOResume.sort_values('duration (seconds)')
# Out:
#               datetime                                           city state  \
# 34491   3/3/2004 21:47                                     healdsburg    ca
# 33727  3/27/2004 18:30                                    canandaigua    ny
# 33731  3/27/2004 22:25                aachen (near cologne) (germany)   NaN
# 32699  3/21/2004 20:00                            onion lake (canada)    sk
# 32707  3/21/2004 24:00                               alberta (canada)    ab
# 33003  3/22/2004 19:00                                     santa cruz    ca
# 32031  3/17/2004 14:00                                           bend    or
# 34649   3/4/2004 20:42                                  san francisco    ca
# 31855  3/16/2004 22:10                                san luis obispo    ca
# 33008  3/22/2004 23:00  motherwell (n. lanarkshire co.) (uk/scotland)   NaN
# 34783   3/5/2004 22:30                         gold coast (australia)   NaN
# ...
